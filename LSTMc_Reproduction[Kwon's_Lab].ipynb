# %% [markdown]
# <a href="https://colab.research.google.com/github/Emkon/Live_Projects/blob/main/LSTMc_Reproduction%5BKwon's_Lab%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "tensorflow>=2.12" numpy pandas matplotlib scipy scikit-learn

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.config.list_physical_devices("GPU"))
# Out:
# 2.19.0
# []
